# %% [markdown]
# Weekly Exercise 1
# Perbaiki script berikut sehingga tidak muncul error.
#
# <pre>
# panjang = 20,5
# lebar = 25
# tinggi = 10
#
# keliling = 2*(panjang+lebar)
# luas = panjang*/lebar
# volum = panjang*lebar*tiggi
#
# print("Panjang = " + 'panjang')
# printl("Lebar = ' + lebar)
# print('Tinggi = "  tinggi)
# printl("Keliling = "  'kelling')
# print("Volume = " + volume)

# %%
panjang = 20.5
lebar = 25
tinggi = 10

keliling = 2* ( panjang+lebar )
luas = panjang * lebar
volume = panjang * lebar * tinggi

print("Panjang =",panjang)
print("Lebar =",lebar)
print("Tinggi =",tinggi)
print("Keliling =",keliling)
print("Volume =",volume)

#Zulfa Nashihin 2420506036
# Out:
# Panjang = 20.5
# Lebar = 25
# Tinggi = 10
# Keliling = 91.0
# Volume = 5125.0

# %% [markdown]
# Weekly Exercise 2
#
# ![image.png](data:image/png;base64,...)
#
# Berdasarkan data di atas, buatlah sebuah program untuk menampilkan data-data berikut :
# 1. Rata-rata nilai Shafira pada kedua mata kuliah
# 2. Jumlah nilai Hanif dan Andi untuk semua mata kuliah
# 3. Rata-rata nilai Widya, Dhanar, Hikma dan Nedia pada masing-masing mata kuliah
# 3. Rata-rata nilai mata kuliah Kalkulus 1 untuk semua mahasiswa
# 4. Rata-rata nilai mata kuliah Metode Statistika untuk semua mahasiswa
#
# Dengan ketentuan gunakan variabel agar memudahkan dalam menampilkan hasil

# %%
A = (85+75)/2 #A adalah Rata-rata nilai Shafira pada kedua mata kuliah

B = (75+90+70+75) #B adalah jumlah nilai Hanif dan Andi untuk kedua mata kuliah

C_k = (85+85+80+95)/4 #C_k adalah Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Kalkulus 1
C_m = (85+85+75+80)/4 #C_m adalah Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Metode Statistika

D = (85+80+75+95+85+75+70+85+80)/9 #D adalah Rata-rata nilai mata kuliah kalkulus 1 dari semua mahasiswa

E = (75+90+80+80+85+90+75+85+75)/9 #E adalah Rata-rata nilai mata kuliah Metode Statistika dari semua mahasiswa

print ("1.Rata-rata nilai Shafira pada kedua mata kuliah =",A)
print ("2.Jumlah nilai Hanif dan Andi untuk semua mata kuliah =",B)
print ("3.Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Kalkulus 1 =",C_k)
print ("  Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Metode Statistika =",C_m)
print ("4.Rata-rata nilai mata kuliah kalkulus 1 untuk semua mahasiswa =",D)
print ("5.Rata-rata nilai mata kuliah Metode Statistika untuk semua mahasiswa =",E)

#Zulfa Nashihin 2420506036
# Out:
# 1.Rata-rata nilai Shafira pada kedua mata kuliah = 80.0
# 2.Jumlah nilai Hanif dan Andi untuk semua mata kuliah = 310
# 3.Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Kalkulus 1 = 86.25
#   Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Metode Statistika = 81.25
# 4.Rata-rata nilai mata kuliah kalkulus 1 untuk semua mahasiswa = 81.11111111111111
# 5.Rata-rata nilai mata kuliah Metode Statistika untuk semua mahasiswa = 81.66666666666667

# %% [markdown]
# Weekly Exercise 3
#
# Diketahui Dwi adalah seorang karyawan pabrik swasta yang telah bekerja selama 10 tahun. Setiap hari Dwi bekerja selama 8 jam. Prosedur penerimaan honor dari perusahaan ditentukan dengan cara jumlah jam masuk dikali dengan Rp 30.000,-.
#
# Buatlah sebuah program untuk menampilkan data berikut:
# 1. Gaji pada bulan Agustus jika Dwi tidak masuk kerja selama 3 hari, berapa gaji yang diterima oleh Dwi.
# 2. Apabila terdapat tunjangan bagi karyawan yang bekerja lebih dari 5 tahun sebesar 10% dari total gaji yang diterima setiap bulan, tentukan jumlah tunjangan yang diterima oleh Dwi pada bulan Agustus.
# 3. Apabila pada bulan Agustus Dwi mendapatkan tugas lembur selama 5 jam, tentukan gaji total yang diterima oleh Dwi pada bulan Agustus. (upah lembur : Rp 10.000,- per jam)

# %%
jam_kerja_perhari = 8
gaji_perjam = 30000
Agustus = 31
hari_masuk = Agustus - 3
persen = 10/100
tugas_lembur = 5
upah_lembur_perjam = 10000
#soal nomor 1
Gaji_bulan_Agustus = hari_masuk*jam_kerja_perhari*gaji_perjam
#soal nomor 2
Tunjangan_Agustus = persen*Gaji_bulan_Agustus
#soal nomor 3
Gaji_total_Agustus = Gaji_bulan_Agustus+Tunjangan_Agustus+tugas_lembur*upah_lembur_perjam
print ("1.Gaji pada bulan Agustus jika tidak masuk selama 3 hari = Rp.",Gaji_bulan_Agustus)
print ("2.Jumlah tunjangan yang diterima oleh Dwi pada bulan Agustus = Rp.",Tunjangan_Agustus)
print ("3.Gaji total yang diterima oleh Dwi pada bulan Agustus = Rp.",Gaji_total_Agustus)

#Zulfa Nashihin 2420506036
# Out:
# 1.Gaji pada bulan Agustus jika tidak masuk selama 3 hari = Rp. 6720000
# 2.Jumlah tunjangan yang diterima oleh Dwi pada bulan Agustus = Rp. 672000.0
# 3.Gaji total yang diterima oleh Dwi pada bulan Agustus = Rp. 7442000.0
