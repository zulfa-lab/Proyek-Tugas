# %% [markdown]
# **Say hello to python**

# %%
print('Hello,Python')
# Out:
# Hello,Python

# %% [markdown]
# Cetak nama dan NIM

# %%
#Mencetak nama dan NIM
print('ZulfaNashihin,2420506036'); #sintak untuk menampilkan
# Out:
# ZulfaNashihin,2420506036

# %% [markdown]
# Biodata

# %%
print('Nama         :Zulfa Nashihin')
print('NPM          :2420506036')
print('Alamat       :Canguk,Magelang')
print('Tinggi Badan :160 cm')
print('Berat Badan  :50 kg')
# Out:
# Nama         :Zulfa Nashihin
# NPM          :2420506036
# Alamat       :Canguk,Magelang
# Tinggi Badan :160 cm
# Berat Badan  :50 kg

# %% [markdown]
# Mencari tahu versi python yang digunakan

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %% [markdown]
# Praktik untuk menampilkan mengenai jurusan Teknik Elektro,Mekatronika,dan Informasi.

# %%
print('\033[1m'+'UNIVERSITAS TIDAR'+'\033[0m')
print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2024 pada tanggal 1 April 2014.')

print('\n\033[1m'+'JURUSAN TEKNIK ELEKTRO,MEKATRONIKA DAN INFORMASI'+'\033[0m')
print('Jurusan Teknik Elektro,Mekatronika,dan Informasi terdiri atas tiga program studi antara lain:')
print('   1. S1 Teknik Elektro \x1b[3m(Bachelor of Electrical Engineering)\x1b[0m')
print('   2. S1 Teknologi Informasi \x1b[3m(Bachelor of Information Technology)\x1b[0m')
print('   3. S1 Teknik Mekatronika \x1b[3m(Bachelor of Mechatronics Engineering)')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2024 pada tanggal 1 April 2014.
#
# JURUSAN TEKNIK ELEKTRO,MEKATRONIKA DAN INFORMASI
# Jurusan Teknik Elektro,Mekatronika,dan Informasi terdiri atas tiga program studi antara lain:
#    1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#    2. S1 Teknologi Informasi (Bachelor of Information Technology)
#    3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)
