# %%
# Weekly Exercise 1 Zulfa Nashihin 2420506036

Age =int(input('Masukkan Umur Anda :'))
if Age >= 17:
  print("Boleh Membuat SIM")
else:
    print("Tidak Boleh Membuat SIM")
# Out:
# Masukkan Umur Anda :20
# Boleh Membuat SIM

# %%
#Weekly Exercise 2 Zulfa Nashihin 2420506036
Nilai =int(input('Masukkan Nilai :'))

if Nilai >= 90:
  print("Grade = A")
elif Nilai >=80:
  print("Grade = B+")
elif Nilai >= 70:
  print("Grade = B")
elif Nilai >= 60:
  print("Grade = C+")
elif Nilai >= 50:
  print("Grade = C")
elif Nilai >= 40:
  print("Grade = D")
else:
    print("Grade = E")
# Out:
# Masukkan Nilai :30
# Grade = E

# %%
# Weekly Exercise 3 Zulfa Nashihin 2420506036
Nilai =float(input('Masukkan Nilai :'))

if Nilai >= 80.00:
  print("Grade = A")
elif Nilai >=77.50:
  print("Grade = A-")
elif Nilai >= 75.00:
  print("Grade = A/B")
elif Nilai >= 72.50:
  print("Grade = B+")
elif Nilai >= 70.00:
  print("Grade = B")
elif Nilai >= 67.50:
  print("Grade = B-")
elif Nilai >= 65.00:
  print("Grade = B/C")
elif Nilai >= 62.50:
  print("Grade = C+")
elif Nilai >= 60.00:
  print("Grade = C")
elif Nilai >= 55.00:
  print("Grade = C-")
elif Nilai >= 50.00:
  print("Grade = C/D")
elif Nilai >= 45.00:
  print("Grade = D+")
elif Nilai >= 40.00:
  print("Grade = D")
else:
  print("Grade = E")
# Out:
# Masukkan Nilai :30
# Grade = E
